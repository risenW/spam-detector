# %% [markdown]
# The [SPAM](https://www.kaggle.com/uciml/sms-spam-collection-dataset) dataset contains 5572 SMS messages and a label. Using this dataset, you are going to create a machine learning model that learns to detect "spam" or not "spam".

# %% [markdown]
# ## Imports Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pickle

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout


from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import wordcloud

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /Users/mac/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # SIMPLE EDA

# %%
df = pd.read_csv("spam.csv",encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# The Columns 2,3,4 will be dropped as they contain no relevant information

# %%
data = df.copy()
data.drop(columns=["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], inplace=True)
data = data.rename(columns={"v1":"label", "v2":"text"})

# %%
data.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Distribution of the label variable

# %% [markdown]
# The dataset contains 4825 ham and 747 spam messages.

# %%
data.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
sns.countplot(data['label'])
plt.show()
# Out:
# /Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Convert labels numerical format

# %%
data['label'] = data['label'].map( {'spam': 1, 'ham': 0} )
data.head()
# Out:
#    label                                               text
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## FEATURE ENGINEERING AND PREPROCESSING

# %%
##add the length of the text as a feature
data['text_length'] = data['text'].apply(len)

# %%
data.head(10)
# Out:
#    label                                               text  text_length
# 0      0  Go until jurong point, crazy.. Available only ...          111
# 1      0                      Ok lar... Joking wif u oni...           29
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...          155
# 3      0  U dun say so early hor... U c already then say...           49
# 4      0  Nah I don't think he goes to usf, he lives aro...           61
# 5      1  FreeMsg Hey there darling it's been 3 week's n...          148
# 6      0  Even my brother is not like to speak with me. ...           77
# 7      0  As per your request 'Melle Melle (Oru Minnamin...          160
# 8      1  WINNER!! As a valued network customer you have...          158
# 9      1  Had your mobile 11 months or more? U R entitle...          154

# %%
data.hist(column='text_length',by='label',bins=60,figsize=(12,5));
# plt.xlim(-40,950);

# %% [markdown]
# Spam(1) messages are generally longer than ham (0) messages:
# Majority of ham has length below 100, for spam it is above 100. This extra feature (text_length) may prove useful to our model.

# %%
data_ham  = data[data['label'] == 0].copy()
data_spam = data[data['label'] == 1].copy()

# %% [markdown]
# WordClouds

# %%
def show_wordcloud(text, title):
    text = ' '.join(text['text'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)
    
    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,background_color='lightgrey',
                    colormap='viridis', width=800, height=600).generate(text)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)  
    plt.axis('off')
    plt.title(title, fontsize=20 )
    plt.show()

# %% [markdown]
# ### WordCloud: Ham messages

# %%
show_wordcloud(data_ham, "Ham messages")

# %% [markdown]
# ### WordCloud: Spam messages

# %%
show_wordcloud(data_spam, "Spam messages")

# %% [markdown]
# Notice that majority of the word in Spam messages contains terms like FREE, CALL, URGENT. These terms will serve as important features to our model.

# %% [markdown]
# Next, we'll do some NLP preprocessing task in the order shown below:
#
# * Puntuation and stopword removal
# * Tokenization
# * Vectorization and
# * TF-IDF weighting

# %% [markdown]
# ### Punctuation
# **We use the punctuation list from the string library:**

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.corpus import stopwords
stopwords.words("english")[0:20]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his']

# %% [markdown]
# **With the above lists for punctuation characters and stop words, we define a function to remove these from the text**
# **This function also converts all text to lowercase**

# %%
def remove_punctuation_and_stopwords(text):
    
    clean_txt = [ch for ch in text if ch not in string.punctuation]
    clean_txt = "".join(clean_txt).split()
    
    clean_txt = [word.lower() for word in clean_txt if word.lower() not in stopwords.words("english")]
        
    return clean_txt

# %%
data['text'].apply(remove_punctuation_and_stopwords)
# Out:
# 0       [go, jurong, point, crazy, available, bugis, n...
# 1                          [ok, lar, joking, wif, u, oni]
# 2       [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3           [u, dun, say, early, hor, u, c, already, say]
# 4       [nah, dont, think, goes, usf, lives, around, t...
#                               ...
# 5567    [2nd, time, tried, 2, contact, u, u, å£750, po...
# 5568                   [ì, b, going, esplanade, fr, home]
# 5569                     [pity, mood, soany, suggestions]
# 5570    [guy, bitching, acted, like, id, interested, b...
# 5571                                   [rofl, true, name]
# Name: text, Length: 5572, dtype: object

# %%
from sklearn.model_selection import train_test_split

X = data['text'].values
y = data['label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from numpy import array
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.callbacks import EarlyStopping

# %%
# prepare tokenizer
t = Tokenizer()
t.fit_on_texts(X_train)
vocab_size = len(t.word_index) + 1

# integer encode the documents
encoded_train = t.texts_to_sequences(X_train)
encoded_test = t.texts_to_sequences(X_test)

print(encoded_train[0:2])
# Out:
# [[38, 30, 8, 5, 273, 1989, 81, 116, 26, 11, 1656, 322, 10, 53, 18, 299, 30, 349, 1990], [799, 15, 2555, 1442, 1127, 192, 2556, 171, 12, 98, 1991, 44, 195, 1657, 2557, 1992, 2558, 21, 9, 4, 203, 1025, 225]]

# %%
# pad documents to a max length of 4 words
max_length = 10
padded_train = pad_sequences(encoded_train, maxlen=max_length, padding='post')
padded_test = pad_sequences(encoded_test, maxlen=max_length, padding='post')

print(padded_train)
# Out:
# [[  11 1656  322 ...   30  349 1990]
#  [1657 2557 1992 ...  203 1025  225]
#  [ 113   83 1443 ... 3794 3795    0]
#  ...
#  [1477   30 2063 ... 2064    0    0]
#  [ 763 1679 1161 ...    0    0    0]
#  [   8  155   20 ...  175    0    0]]

# %%
# define the model
model = Sequential()
model.add(Embedding(vocab_size, 8, input_length=max_length))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# summarize the model
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 10, 8)             63640
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 80)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 500)               40500
# _________________________________________________________________
# dense_18 (Dense)             (None, 200)               100200
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 224,541
# Trainable params: 224,541
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# fit the model
# model.fit(padded_sms, y_train, epochs=5, verbose=1)

model.fit(x=padded_train, 
          y=y_train, 
          epochs=10,
          validation_data=(padded_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/10
# 140/140 [==============================] - 0s 2ms/step - loss: 8.4469e-06 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9776
# Epoch 2/10
# 140/140 [==============================] - 0s 2ms/step - loss: 6.9563e-06 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9776
# Epoch 3/10
# 140/140 [==============================] - 0s 2ms/step - loss: 5.7952e-06 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9776
# Epoch 4/10
# 140/140 [==============================] - 0s 2ms/step - loss: 4.8851e-06 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9776
# Epoch 5/10
# 140/140 [==============================] - 0s 2ms/step - loss: 4.1505e-06 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9776
# Epoch 6/10
# 140/140 [==============================] - 0s 2ms/step - loss: 3.5618e-06 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9776
# Epoch 00006: early stopping

# %%
# evaluate the model
loss, accuracy = model.evaluate(padded_test, y_test, verbose=0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# Accuracy: 97.757846

# %%
preds = model.predict_classes(padded_test)

# %%
def c_report(y_true, y_pred):
    print("Classification Report")
    print(classification_report(y_true, y_pred))
    acc_sc = accuracy_score(y_true, y_pred)
    print("Accuracy : "+ str(acc_sc))
    return acc_sc


def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,  
                cmap="Blues", cbar=False)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
c_report(y_test, preds)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       965
#            1       0.98      0.85      0.91       150
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Accuracy : 0.9775784753363229
# 0.9775784753363229

# %%
plot_confusion_matrix(y_test, preds)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-130-743cd273c49e>", line 1, in <module>
#     plot_confusion_matrix(y_test, preds)
#   File "<ipython-input-129-c8597e2d6aab>", line 10, in plot_confusion_matrix
#     mtx = confusion_matrix(y_true, y_pred)
#   File "<ipython-input-127-327279bd0f70>", line 10, in confusion_matrix
#     mtx = confusion_matrix(y_true, y_pred)
#   File "<ipython-input-127-327279bd0f70>", line 10, in confusion_matrix
#     mtx = confusion_matrix(y_true, y_pred)
#   File "<ipython-input-127-327279bd0f70>", line 10, in confusion_matrix
#     mtx = confusion_matrix(y_true, y_pred)
#   [Previous line repeated 2957 more times]
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RecursionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/inspect.py", line 70, in ismodule
#     return isinstance(object, types.ModuleType)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-130-743cd273c49e> in <module>
# ----> 1 plot_confusion_matrix(y_test, preds)
#
# <ipython-input-129-c8597e2d6aab> in plot_confusion_matrix(y_true, y_pred)
#       9 def plot_confusion_matrix(y_true, y_pred):
# ---> 10     mtx = confusion_matrix(y_true, y_pred)
#      11     sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,
#
# <ipython-input-127-327279bd0f70> in confusion_matrix(y_true, y_pred)
#       9 def confusion_matrix(y_true, y_pred):
# ---> 10     mtx = confusion_matrix(y_true, y_pred)
#      11     sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-127-327279bd0f70> in confusion_matrix(y_true, y_pred)
#       9 def confusion_matrix(y_true, y_pred):
# ---> 10     mtx = confusion_matrix(y_true, y_pred)
#      11     sns.heatmap(mtx, annot=True, fmt='d', linewidths=.5,
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'RecursionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     448     # quarter of the traceback (250 frames by default) is repeats, and find the
#     449     # first frame (from in to out) that looks different.
# --> 450     if not is_recursion_error(etype, value, records):
#     451         return len(records), 0
#     452
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/IPython/core/ultratb.py in is_recursion_error(etype, value, records)
#     435     return (etype is recursion_error_type) \
#     436            and "recursion" in str(value).lower() \
# --> 437            and len(records) > _FRAME_RECURSION_LIMIT
#     438
#     439 def find_recursion(etype, value, records):
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ## SAVING MODEL AND TOKENIZER

# %%
model.save("spam_model")
# Out:
# WARNING:tensorflow:From /Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/mac/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: spam_model/assets

# %%
with open('spam_model/tokenizer.pkl', 'wb') as output:
    pickle.dump(t, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## LOADING AND EVALUATING MODEL

# %%
s_model = tf.keras.models.load_model("spam_model")

with open('spam_model/tokenizer.pkl', 'rb') as input:
    tokener = pickle.load(input)
 
s_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 10, 8)             63640
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 80)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 500)               40500
# _________________________________________________________________
# dense_18 (Dense)             (None, 200)               100200
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 224,541
# Trainable params: 224,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
sms = [X_test[2]]
print(sms)
print(y_test[1], y_test[2])

sms_proc = tokener.texts_to_sequences(sms)
sms_proc = pad_sequences(sms_proc, maxlen=max_length, padding='post')
# Out:
# ['We know someone who you know that fancies you. Call 09058097218 to find out who. POBox 6, LS15HB 150p']
# 0 1

# %%
if (str(s_model.predict_classes(sms_proc)[0]) == '0'):
    print("yes")

# %%
s_model.predict_classes(sms_proc)[0]
# Out:
# array([1], dtype=int32)
